# %%
import os
import pandas as pd

# %%
from clickhouse_driver import Client

host = 'localhost'
port = 19000
user = 'default'
password = 'changeme'

client = Client(host=host, port=port, user=user, password=password)

result = client.execute('SHOW DATABASES')
print(result)
# Out:
# [('INFORMATION_SCHEMA',), ('default',), ('information_schema',), ('system',)]

# %%
df_district = pd.read_csv('district.csv', encoding='cp1251', sep=';')

# %%
df_orders= pd.read_csv('orders.csv', encoding='cp1251', sep=';')

# %%
client.connection
# Out:
# <Connection(dsn=clickhouse://default:***@localhost:19000/, compression=0)>

# %%
from sqlalchemy import create_engine
import sqlalchemy as sa
import pandas as pd

engine = create_engine('clickhouse://default:changeme@localhost:18123/default')

with engine.connect() as connection:
    result = connection.execute(sa.text('SHOW DATABASES'))
    res = result.fetchall()

print(res)
# Out:
# [('INFORMATION_SCHEMA',), ('default',), ('information_schema',), ('system',)]

# %%
print(pd.io.sql.get_schema(df_orders, name='orders', con=engine))
# Out:
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(pd.io.sql.get_schema(df_orders, name='orders', con=engine))
#
# File ~/optimization_sql/.venv/lib/python3.10/site-packages/pandas/io/sql.py:2924, in get_schema(frame, name, keys, con, dtype, schema)
#    2902 """
#    2903 Get the SQL db table schema for the given frame.
#    2904
#    (...)
#    2921     Optional specifying the schema to be used in creating the table.
#    2922 """
#    2923 with pandasSQL_builder(con=con) as pandas_sql:
# -> 2924     return pandas_sql._create_sql_schema(
#    2925         frame, name, keys=keys, dtype=dtype, schema=schema
#    2926     )
#
# File ~/optimization_sql/.venv/lib/python3.10/site-packages/pandas/io/sql.py:2083, in SQLDatabase._create_sql_schema(self, frame, table_name, keys, dtype, schema)
#    2066 def _create_sql_schema(
#    2067     self,
# ...

# %%
df_orders.head(0).to_sql(
    name='orders',
    con=engine,
    if_exists='replace',  # или 'append'
)
# Out:
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df_orders.head(0).to_sql(
#       2     name='orders',
#       3     con=engine,
#       4     if_exists='replace',  # или 'append'
#       5     index=False
#       6 )
#
# File ~/optimization_sql/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
